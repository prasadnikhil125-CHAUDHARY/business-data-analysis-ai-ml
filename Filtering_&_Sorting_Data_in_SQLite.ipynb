# %% [markdown]
# <a href="https://colab.research.google.com/github/prasadnikhil125-CHAUDHARY/business-data-analysis-ai-ml/blob/main/Filtering_%26_Sorting_Data_in_SQLite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Library
import sqlite3
import requests
import pandas as pd

# %% [markdown]
# https://github.com/YBIFoundation/SQL/raw/main/DigitalMarketingAnalytics.sql

# %%
url = 'https://github.com/YBIFoundation/SQL/raw/main/DigitalMarketingAnalytics.sql'
sql_script = requests.get(url).text

# %%
sql_script
# Out:
# 'BEGIN TRANSACTION;\nCREATE TABLE marketing(\nCustomer_ID INTEGER PRIMARY KEY,\nGender TEXT,\nAge INTEGER,\nCity TEXT,\nDevice TEXT,\nMarketing_Channel TEXT,\nCampaign TEXT,\nAd_Clicks INTEGER,\nImpressions INTEGER,\nSpend INTEGER,\nPurchased TEXT,\nSales INTEGER,\nOrder_Value INTEGER,\nPurchase_Date TEXT,\nCustomer_Segment TEXT\n);\nINSERT INTO "marketing" VALUES(100001,\'Male\',19,\'Hyderabad\',\'Mobile\',\'Google\',\'Summer Sale\',1106,18370,11890,\'Yes\',2979,2979,\'2025-04-30\',\'Returning\');\nINSERT INTO "marketing" VALUES(100002,\'Male\',53,\'Delhi\',\'Mobile\',\'Instagram\',\'Festive Offer\',839,9615,3443,\'No\',0,0,\'2025-12-24\',\'New\');\nINSERT INTO "marketing" VALUES(100003,\'Female\',39,\'Mumbai\',\'Mobile\',\'Facebook\',\'Summer Sale\',195,3669,1853,\'No\',0,0,\'2025-01-23\',\'New\');\nINSERT INTO "marketing" VALUES(100004,\'Female\',52,\'Delhi\',\'Tablet\',\'Google\',\'Flash Sale\',1180,12350,18022,\'Yes\',3065,3065,\'2025-05-29\',\'Returning\');\nINSERT INTO "market
# ...

# %%
# Create Db
conn = sqlite3.connect(":memory:")
conn.executescript(sql_script)

# %%
# Helper function
def sql(query):
  return pd.read_sql(query, conn)

# %%
# Check for db table
sql("SELECT name FROM sqlite_master Where type = 'table' ;")
# Out:
#         name
# 0  marketing

# %%
# Total records
sql("SELECT COUNT(*) FROM marketing;")
# Out:
#    COUNT(*)
# 0      5000

# %% [markdown]
# ## **Where**

# %%
sql("SELECT * FROM marketing WHERE city = 'Delhi' ;")
# Out:
#       Customer_ID  Gender  Age   City   Device Marketing_Channel  \
# 0          100002    Male   53  Delhi   Mobile         Instagram
# 1          100004  Female   52  Delhi   Tablet            Google
# 2          100009    Male   25  Delhi   Mobile          Facebook
# 3          100012  Female   49  Delhi   Tablet             Email
# 4          100022  Female   34  Delhi  Desktop            Google
# ...           ...     ...  ...    ...      ...               ...
# 1113       104977  Female   60  Delhi   Mobile            Google
# 1114       104979    Male   48  Delhi   Mobile            Google
# 1115       104988    Male   36  Delhi   Tablet          Facebook
# 1116       104990  Female   29  Delhi   Mobile            Google
# 1117       104991    Male   36  Delhi  Desktop           YouTube
#
#            Campaign  Ad_Clicks  Impressions  Spend Purchased  Sales  \
# 0     Festive Offer        839         9615   3443        No      0
# ...

# %% [markdown]
# ### **Comparison Operators**
#
# | Operator     | Meaning                  |
# | ------------ | ------------------------ |
# | `=`          | Equal to                 |
# | `>`          | Greater than             |
# | `<`          | Less than                |
# | `>=`         | Greater than or equal to |
# | `<=`         | Less than or equal to    |
# | `!=` or `<>` | Not equal to             |

# %%
sql("SELECT * from Marketing WHERE Spend >5000 ;")
# Out:
#       Customer_ID  Gender  Age       City   Device Marketing_Channel  \
# 0          100001    Male   19  Hyderabad   Mobile            Google
# 1          100004  Female   52      Delhi   Tablet            Google
# 2          100005    Male   32    Chennai   Mobile         Instagram
# 3          100006    Male   56  Hyderabad   Mobile            Google
# 4          100007    Male   20    Chennai   Mobile            Google
# ...           ...     ...  ...        ...      ...               ...
# 3248       104995  Female   37  Hyderabad   Mobile             Email
# 3249       104997  Female   35     Mumbai   Mobile             Email
# 3250       104998  Female   44  Hyderabad  Desktop          Facebook
# 3251       104999    Male   35     Mumbai   Mobile         Instagram
# 3252       105000  Female   19     Mumbai   Mobile         Instagram
#
#            Campaign  Ad_Clicks  Impressions  Spend Purchased  Sales  \
# 0       Summer Sale       1106        18370  11890       Yes   2979
# ...

# %% [markdown]
# ### **AND, OR, NOT**
#
# - AND
#
# Both conditions must be true.
#
# - OR
#
# At least one condition must be true.
#
# - OR
#
# At least one condition must be true.

# %%
# And
sql("SELECT * from marketing WHERE city = 'Delhi' AND Purchased = 'Yes' ;")
# Out:
#      Customer_ID  Gender  Age   City   Device Marketing_Channel  \
# 0         100004  Female   52  Delhi   Tablet            Google
# 1         100012  Female   49  Delhi   Tablet             Email
# 2         100027  Female   53  Delhi   Mobile             Email
# 3         100028    Male   40  Delhi   Mobile            Google
# 4         100048  Female   30  Delhi  Desktop          Facebook
# ..           ...     ...  ...    ...      ...               ...
# 182       104945    Male   56  Delhi   Mobile         Instagram
# 183       104954  Female   34  Delhi   Mobile         Instagram
# 184       104962    Male   56  Delhi   Mobile           YouTube
# 185       104976    Male   33  Delhi  Desktop            Google
# 186       104988    Male   36  Delhi   Tablet          Facebook
#
#           Campaign  Ad_Clicks  Impressions  Spend Purchased  Sales  \
# 0       Flash Sale       1180        12350  18022       Yes   3065
# ...

# %%
# Or
sql("SELECT * from marketing WHERE Marketing_Channel = 'Google' OR Marketing_Channel = 'Instagram';")
# Out:
#       Customer_ID  Gender  Age       City  Device Marketing_Channel  \
# 0          100001    Male   19  Hyderabad  Mobile            Google
# 1          100002    Male   53      Delhi  Mobile         Instagram
# 2          100004  Female   52      Delhi  Tablet            Google
# 3          100005    Male   32    Chennai  Mobile         Instagram
# 4          100006    Male   56  Hyderabad  Mobile            Google
# ...           ...     ...  ...        ...     ...               ...
# 2924       104990  Female   29      Delhi  Mobile            Google
# 2925       104992    Male   50  Bangalore  Mobile         Instagram
# 2926       104993  Female   38  Hyderabad  Mobile         Instagram
# 2927       104999    Male   35     Mumbai  Mobile         Instagram
# 2928       105000  Female   19     Mumbai  Mobile         Instagram
#
#            Campaign  Ad_Clicks  Impressions  Spend Purchased  Sales  \
# 0       Summer Sale       1106        18370  11890       Yes   2979
# ...

# %%
# Not
sql("SELECT * from marketing WHERE Not City = 'Delhi' ;")
# Out:
#       Customer_ID  Gender  Age       City   Device Marketing_Channel  \
# 0          100001    Male   19  Hyderabad   Mobile            Google
# 1          100003  Female   39     Mumbai   Mobile          Facebook
# 2          100005    Male   32    Chennai   Mobile         Instagram
# 3          100006    Male   56  Hyderabad   Mobile            Google
# 4          100007    Male   20    Chennai   Mobile            Google
# ...           ...     ...  ...        ...      ...               ...
# 3877       104996  Female   54  Hyderabad   Mobile           YouTube
# 3878       104997  Female   35     Mumbai   Mobile             Email
# 3879       104998  Female   44  Hyderabad  Desktop          Facebook
# 3880       104999    Male   35     Mumbai   Mobile         Instagram
# 3881       105000  Female   19     Mumbai   Mobile         Instagram
#
#            Campaign  Ad_Clicks  Impressions  Spend Purchased  Sales  \
# 0       Summer Sale       1106        18370  11890       Yes   2979
# ...

# %%
# Between
sql("SELECT * from marketing WHERE Spend BETWEEN 5000 AND 10000 ;")
# Out:
#       Customer_ID  Gender  Age       City   Device Marketing_Channel  \
# 0          100005    Male   32    Chennai   Mobile         Instagram
# 1          100011    Male   50       Pune  Desktop            Google
# 2          100015    Male   22       Pune  Desktop            Google
# 3          100018    Male   46    Chennai  Desktop            Google
# 4          100027  Female   53      Delhi   Mobile             Email
# ...           ...     ...  ...        ...      ...               ...
# 1405       104991    Male   36      Delhi  Desktop           YouTube
# 1406       104992    Male   50  Bangalore   Mobile         Instagram
# 1407       104994  Female   26       Pune   Mobile           YouTube
# 1408       104999    Male   35     Mumbai   Mobile         Instagram
# 1409       105000  Female   19     Mumbai   Mobile         Instagram
#
#            Campaign  Ad_Clicks  Impressions  Spend Purchased  Sales  \
# 0        Flash Sale        652        12141   5393        No      0
# ...

# %%
# In
sql("SELECT * from marketing WHERE Marketing_Channel = 'Google' OR Marketing_Channel = 'Instagram';")
# Out:
#       Customer_ID  Gender  Age       City  Device Marketing_Channel  \
# 0          100001    Male   19  Hyderabad  Mobile            Google
# 1          100002    Male   53      Delhi  Mobile         Instagram
# 2          100004  Female   52      Delhi  Tablet            Google
# 3          100005    Male   32    Chennai  Mobile         Instagram
# 4          100006    Male   56  Hyderabad  Mobile            Google
# ...           ...     ...  ...        ...     ...               ...
# 2924       104990  Female   29      Delhi  Mobile            Google
# 2925       104992    Male   50  Bangalore  Mobile         Instagram
# 2926       104993  Female   38  Hyderabad  Mobile         Instagram
# 2927       104999    Male   35     Mumbai  Mobile         Instagram
# 2928       105000  Female   19     Mumbai  Mobile         Instagram
#
#            Campaign  Ad_Clicks  Impressions  Spend Purchased  Sales  \
# 0       Summer Sale       1106        18370  11890       Yes   2979
# ...

# %%
sql("SELECT * from marketing WHERE Marketing_Channel IN ('Google','Instagram');")
# Out:
#       Customer_ID  Gender  Age       City  Device Marketing_Channel  \
# 0          100001    Male   19  Hyderabad  Mobile            Google
# 1          100002    Male   53      Delhi  Mobile         Instagram
# 2          100004  Female   52      Delhi  Tablet            Google
# 3          100005    Male   32    Chennai  Mobile         Instagram
# 4          100006    Male   56  Hyderabad  Mobile            Google
# ...           ...     ...  ...        ...     ...               ...
# 2924       104990  Female   29      Delhi  Mobile            Google
# 2925       104992    Male   50  Bangalore  Mobile         Instagram
# 2926       104993  Female   38  Hyderabad  Mobile         Instagram
# 2927       104999    Male   35     Mumbai  Mobile         Instagram
# 2928       105000  Female   19     Mumbai  Mobile         Instagram
#
#            Campaign  Ad_Clicks  Impressions  Spend Purchased  Sales  \
# 0       Summer Sale       1106        18370  11890       Yes   2979
# ...

# %% [markdown]
# ### **LIKE**
#
# Used for pattern matching.
#
# | Pattern | Meaning       |
# | ------- | ------------- |
# | `A%`    | Starts with A |
# | `%A`    | Ends with A   |
# | `%A%`   | Contains A    |

# %%
sql("SELECT * from marketing WHERE Campaign LIKE '%Sale%' ;")
# Out:
#       Customer_ID  Gender  Age       City   Device Marketing_Channel  \
# 0          100001    Male   19  Hyderabad   Mobile            Google
# 1          100003  Female   39     Mumbai   Mobile          Facebook
# 2          100004  Female   52      Delhi   Tablet            Google
# 3          100005    Male   32    Chennai   Mobile         Instagram
# 4          100007    Male   20    Chennai   Mobile            Google
# ...           ...     ...  ...        ...      ...               ...
# 2537       104994  Female   26       Pune   Mobile           YouTube
# 2538       104995  Female   37  Hyderabad   Mobile             Email
# 2539       104996  Female   54  Hyderabad   Mobile           YouTube
# 2540       104998  Female   44  Hyderabad  Desktop          Facebook
# 2541       104999    Male   35     Mumbai   Mobile         Instagram
#
#          Campaign  Ad_Clicks  Impressions  Spend Purchased  Sales  \
# 0     Summer Sale       1106        18370  11890       Yes   2979
# ...

# %% [markdown]
# ### **ORDER BY**
#
# Used to sort records.
# - ASC = ascending
# - DESC = descending

# %%
sql("SELECT * from marketing ORDER BY Spend DESC ;")
# Out:
#       Customer_ID  Gender  Age       City   Device Marketing_Channel  \
# 0          100253    Male   19       Pune  Desktop            Google
# 1          104975    Male   29     Mumbai   Mobile             Email
# 2          104414    Male   26     Mumbai   Mobile            Google
# 3          102567  Female   37      Delhi  Desktop             Email
# 4          104623  Female   26     Mumbai   Mobile             Email
# ...           ...     ...  ...        ...      ...               ...
# 4995       100726  Female   20      Delhi   Mobile            Google
# 4996       104196    Male   35     Mumbai   Mobile         Instagram
# 4997       102762    Male   25      Delhi   Mobile           YouTube
# 4998       102955    Male   24  Hyderabad   Mobile          Facebook
# 4999       102022    Male   31     Mumbai   Mobile          Facebook
#
#            Campaign  Ad_Clicks  Impressions  Spend Purchased  Sales  \
# 0        New Launch       2473        19636  48430       Yes   2775
# ...

# %%
# Purchased = Yes
sql("SELECT * FROM marketing WHERE Purchased = 'Yes';")
# Out:
#      Customer_ID  Gender  Age       City   Device Marketing_Channel  \
# 0         100001    Male   19  Hyderabad   Mobile            Google
# 1         100004  Female   52      Delhi   Tablet            Google
# 2         100008    Male   33  Hyderabad   Mobile          Facebook
# 3         100012  Female   49      Delhi   Tablet             Email
# 4         100014  Female   46       Pune   Mobile            Google
# ..           ...     ...  ...        ...      ...               ...
# 907       104985    Male   54       Pune   Tablet          Facebook
# 908       104988    Male   36      Delhi   Tablet          Facebook
# 909       104989  Female   28  Bangalore  Desktop            Google
# 910       104998  Female   44  Hyderabad  Desktop          Facebook
# 911       105000  Female   19     Mumbai   Mobile         Instagram
#
#         Campaign  Ad_Clicks  Impressions  Spend Purchased  Sales  Order_Value  \
# ...
